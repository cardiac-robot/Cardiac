# %%
# %matplotlib inline

from pylab import *
import matplotlib.pyplot as plt
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

from scipy.stats import truncnorm

import os.path

import argparse

import qi

'''TODO: in the no-robot condition don't run this script, just take the camera image from the tablet and save it with 
the person_name'''
class RecogniserBN:
    
    def __init__(self, session):
        
#         self.recog_service = session.service("RecognitionService")
        self.recog_file = "RecogniserBN.bif"
        self.loadBN(self.recog_file)
        '''
        Nodes explained: 

        Identity: John, Jim, Mary..
        Range variable because it is easier to change the number of states of the node as the database grows
        
        Face: John's face, Jim's face, Mary's face..        
        See "Identity" variable explanation

        Gender: Labelized variable. Female (0 in Naoqi), Male (1 in Naoqi) 

        Age: Range variable in [0, 75] (because Naoqi age detection is in the range of [0,75] )
        # !!!!!TONY: USE GAUSSIAN FOR P(AGE=a_i)!!!!!
        # !!!!!NOTE: should I decrease the range?!!!!!
        # !!!!!NOTE2: P(I=John|A=26) = this should be a Gaussian curve at mean 26, 
        since John can be 25 and the algorithm might be mistaken. I need to check this!!!!!
        # !!!!!NOTE3: should I use labelized variable instead? Like 0-10, 10-20, 20-30, etc. or smaller ranges? But in that case
        P(A=26) = 40% will not be valid (should be higher confidence)!!!!!
        
        Height: Range variable [50, 240]
        # !!!!!TODO: ASK TONY IF I SHOULD USE HEIGHT (THROUGH KINECT)!!!!!
        # !!!!!TONY: USE GAUSSIAN FOR P(HEIGHT=h_i) (DON'T USE INTERVALS, USE REAL HEIGHT)!!!!!
        "80-90, 91-100, 101-110, 111-120, 121-130, 131-140, 141-150, 151-160, 161-170, 171-180, 
        181-190, 191-200, 201-210, 211-220, 221-230, 231-240"
            or
        "child, very short, short, normal, tall, very tall"
        # !!!!!NOTE: height can be changed into a range variable, 
        but it is more reliable to categorise it in this way, I need to check this!!!!

        Location: Range variable (can be changed to labelized variable). 
        Kitchen, bedroom, living room, office (the places can change depending on the experiment)
        # !!!!!NOTE_COLOMBIA: Not used as the location is the same!!!!!
        
        Time: Range variable
        # !!!!!TONY: USE GAUSSIAN PDF FOR P(TIME=t_i). t_i can be minutes!!!!! 
        # !!!!!SCRATCH THIS ---TONY: USE TIMESLOTS INSTEAD OF HOURS OR MINUTES!!!!!
        # !!!!!NOTE_COLOMBIA: Each patient has a certain timeslot and a day so this is possible to use!!!!!
        # !!!!!NOTE2:7(days)*24(hours)*60(minutes)/5(period) =  - I can change this to 7(days)*6(timeslots in day) = 42
        Time slots: early morning (5.00.01 - 8.00.00), morning (8.00.01 - 12.00.00), afternoon (12.00.01 - 17.00.00), 
        evening (17.00.01 - 21.00.00), night (21.00.01 - 00.00.00), late night (00.00.01 - 5.00.00)!!!!!
        

        '''
        self.updatePriors()
        gnb.showBN(self.r_bn)
        
    def loadBN(self, recog_file):
        # load previous BN from file or create a new BN if the file doesn't exist
        self.recog_file = recog_file
        
        if os.path.isfile(recog_file):
            self.r_bn = gum.loadBN(recog_file)
#             self.loadDB()
        else:
            self.loadDummyData()
            self.r_bn=gum.BayesNet('RecogniserBN')
            self.addNodes()
            self.addArcs()
            self.addCpts()
            
    def saveBN(self, recog_file):
        # save BN before closing the system
        self.recog_file = recog_file
        gum.saveBN(self.r_bn, recog_file)
    
    def loadDummyData(self):
        self.i_labels = ["Unknown","Bahar"]
#         self.num_people = 3
        self.times_people =[["11:00:00",1], ["12:00:00",1]]
        
#     def loadDB(self):
#         if self.num_people < 2:
#             self.num_states_people = 2 
#         else:
#             self.num_states_people = self.num_people
        #TODO: do this part
#         self.num_people = 
        #TODO: get known list from the database for self.i_labels         
        # self.people = [["name","gender","age","height","time"],...]
#         self.i_labels = 
#         self.times_people = # format: [["time_of_session_for_patient_i", numericDayName_for_patient_i],...]
#         self.ages = 
#         self.heights = 
#     def saveDB(self):
#         #TODO: do this part
        
    def addNodes(self):  
        
        # Identity node
        self.identity = gum.LabelizedVariable("I","Identity",0)
        
        for counter in range(0, len(self.i_labels)):
            self.identity.addLabel(self.i_labels[counter])       
        self.I = self.r_bn.add(self.identity)
        
#         # Face node
#         self.face = gum.LabelizedVariable("F","Face",0)
#         for counter in range(0, len(self.i_labels)):
#             self.face.addLabel(self.i_labels[counter]) 
#         self.F = self.r_bn.add(self.face)
        
#         # Accuracy of Face node
#         self.accuracy_face = gum.LabelizedVariable("A_F","Accuracy_Face",0)
#         self.accuracy_labels = ["Reliable", "Not-reliable"]
#         for counter in range(0, len(self.accuracy_labels)):
#             self.accuracy_face.addLabel(self.accuracy_labels[counter])
#         self.A_F = self.r_bn.add(self.accuracy_face)        

#         # Gender node
#         self.gender = gum.LabelizedVariable("G","Gender",0)
#         self.g_labels = ["Female", "Male"]
#         for counter in range(0, len(self.g_labels)):
#             self.gender.addLabel(self.g_labels[counter])
#         self.G = self.r_bn.add(self.gender)
        
#         # Age node
#         self.age_min = 0
#         self.age_max = 75
#         self.age = gum.RangeVariable("A","Age",self.age_min,self.age_max)
#         self.A = self.r_bn.add(self.age)      
        
        # Height node
        self.height_min = 50 # TODO: LOOK AT THIS
        self.height_max = 240 # TODO: LOOK AT THIS
        self.stddev_height = 5 # TODO: LOOK AT THIS
        self.height = gum.RangeVariable("H","Height",self.height_min,self.height_max)
        self.H = self.r_bn.add(self.height)
        
# # # # #         # Location node
# # # # #         self.l_labels = ["Kitchen", "Office"]
# # # # #         self.location = gum.LabelizedVariable("L","Location",0)
# # # # #         for counter in range(0, len(self.l_labels)):
# # # # #             self.location.addLabel(self.l_labels[counter])
# # # # #         self.L = self.r_bn.add(self.location)
        
        # Time node
        self.period = 5 # time is checked every 5 minutes (instead of 1 minute to decrease the time for calculating BN)
        #TODO: ASK TONY ABOUT STDDEV (IS 15 MIN OKAY, OR SHOULD IT BE MORE/LESS. ALSO ASK HIM IF IT IS A GOOD IDEA TO 
        # DISCRETISE IT EVERY 5 MIN INSTEAD OF EVERY MINUTE)
        self.stddev_time = 15/self.period # 15 minutes
        self.num_time_slots = 7*24*60/self.period # 7(days)*24(hours)*60(minutes)/self.period
        self.time_of_day = gum.RangeVariable("T","Time",0,self.num_time_slots-1)
        self.T = self.r_bn.add(self.time_of_day)
        
        
    def addArcs(self):
        #TODO: think about reliability using weightedArc !!!!!
#         self.r_bn.addArc(self.A_F, self.F)
#         self.r_bn.addArc(self.F,self.I)
#         self.r_bn.addArc(self.G,self.I)
#         self.r_bn.addArc(self.A,self.I)
#         self.r_bn.addArc(self.H,self.I)
# #  #       self.r_bn.addArc(self.L,self.I)
# #  #       self.r_bn.addArc(self.T,self.L)
        self.r_bn.addArc(self.T,self.I)
        

    def updateNodes(self, p_name, p_time):
        '''Call the function when a new person added is to the db
        CPT is a property of the BN and not the variable, therefore, 
        to add a new state to a node, it is necessary to copy the previous CPT,
        change it accordingly (normalize it, or change it?), 
        erase the node, redefine the node 
        (e.g. self.face = gum.LabelizedVariable("F","Face",num_people)), 
        add the changed node back to the BN, add the arcs, and add the changed CPT to it
        change the CPT of the child nodes (if necessary?)
        '''
#         self.num_people = self.num_people + 1
#         if self.num_people < 2:
#             self.num_states_people = 2
#         else:
#             self.num_states_people = self.num_people
        
#         # Face node
#         self.F_cpt = self.r_bn.cpt(self.F)[:]
#         #TODO: change cpt!
#         self.r_bn.erase(self.F)
        
#         self.face = gum.LabelizedVariable("F","Face",0)
#         for counter in range(0, len(self.i_labels)):
#             self.face.addLabel(self.i_labels[counter]) 
#         self.F = self.r_bn.add(self.face)
#         self.r_bn.cpt(self.F)[:] = self.F_cpt
        
        # Identity node
        self.I_cpt = self.r_bn.cpt(self.I)[:]
        #TODO: change cpt!
        self.r_bn.erase(self.I)
        self.identity = gum.LabelizedVariable("I","Identity",0)
        self.i_labels.append(p_name)
        for counter in range(0, len(self.i_labels)):
            self.identity.addLabel(self.i_labels[counter])       
        self.I = self.r_bn.add(self.identity)
        self.r_bn.cpt(self.I)[:] = self.I_cpt
        
        self.addArcs()
            
        # add time of the person to the times the people come and update cpt(self.I)['T':{time_i_j}] 
        # where time_i_j is the time the person i_j comes to the session
        self.times_people.append(p_time)
        for time_i in range(0, self.num_time_slots):
            time_curve = norm(loc=time_i,scale=self.stddev_time)
            sum_ps = 0
            time_ps = []
            for counter in range(0, len(self.i_labels)): #TODO: don't include unknown
                tp = self.times_people[counter][0].split(":")
                time_p = (int(self.times_people[counter][1])-1)*24*60/self.period + int(tp[0])*60/self.period + int(tp[1])/self.period
                sum_ps += time_curve.pdf(time_p)
                time_ps.append(time_curve.pdf(time_p))
            if sum_ps != 0:
                norm_time_ps =  [x / sum_ps for x in time_ps]
            else:
                norm_time_ps = time_ps
                norm_time_ps[0] = 1.0 # person is unknown for sure
            sum_changed = 0
            for counter in range(0, len(self.i_labels)):
                if norm_time_ps[counter] < 0.001:
                    norm_time_ps[counter] = 0.001
                sum_changed += norm_time_ps[counter]
            norm_time_ps =  [x / sum_changed for x in norm_time_ps]
            
                # TODO: for every probability that less than 0.001 value after normalisation, change the value to 0.001
                # TODO: if sum_ps is zero, for every probability that less than 0.001 value after normalisation, 
                # change the value to 0.001 and set p("unknown")= 1-sum(other prob) #do this for every classifier!
            self.r_bn.cpt(self.I)[{'T':time_i}] = norm_time_ps
    
    def findTimeSlot(self, times_people):
        for counter in range(0, len(self.i_labels)):
            tp = self.times_people[counter][0].split(":")
            
            time_p = (int(times_people[counter][1])-1)*24*60/self.period + int(tp[0])*60/self.period + int(tp[1])/self.period
    
    def addCpts(self):
             
        # P(A_F), P(F|A_F), P(G), P(A), P(H), P(T) 
#         self.r_bn.cpt(self.A_F).fillWith(1).normalize()
#         self.r_bn.cpt(self.F)[0,:] = 1
#         self.r_bn.cpt(self.F)[1,:] = 1
#         self.r_bn.cpt(self.G).fillWith(1).normalize()
#         self.r_bn.cpt(self.A).fillWith(1).normalize()
#         self.r_bn.cpt(self.H).fillWith(1).normalize()
        self.r_bn.cpt(self.T).fillWith(1).normalize()
        
        # P(I|F), P(I|G), P(I|A), P(I|H), P(I|T)
#         for counter in range(0, len(self.i_labels)):
#             # what it does: self.r_bn.cpt(self.I)[{'F':0}]=1 SAME THING AS: self.r_bn.cpt(self.I)[{'F':"Unknown"}]=[0.5,0.5]
#             self.r_bn.cpt(self.I)[{'F':self.i_labels[counter]}] = 1
#         for counter in range(0, len(self.g_labels)):
#             self.r_bn.cpt(self.I)[{'G':self.g_labels[counter]}] = 1
#         for counter in range(0, self.age_max-self.age_min+1):
#             self.r_bn.cpt(self.I)[{'A':counter}] = 1
#         for counter in range(0, self.height_max-self.height_min+1):
#             self.r_bn.cpt(self.I)[{'H':counter}] = 1

        # TODO: get times_people from database (do this in loadDB)
        # format: [[numericDayName_for_patient_i, "time_of_session_for_patient_i"],...]
        for time_i in range(0, self.num_time_slots):
            time_curve = norm(loc=time_i,scale=self.stddev_time)
            time_ps = []
            sum_ps = 0
            for counter in range(0, len(self.i_labels)): #don't include unknown
                tp = self.times_people[counter][0].split(":")
                time_p = (int(self.times_people[counter][1])-1)*24*60/self.period + int(tp[0])*60/self.period + int(tp[1])/self.period
                time_ps.append(time_curve.pdf(time_p))
                sum_ps += time_curve.pdf(time_p)
            if sum_ps != 0:
                norm_time_ps = [x / sum_ps for x in time_ps]
            self.r_bn.cpt(self.I)[{'T':time_i}] = norm_time_ps
        
        print self.r_bn
        self.ie = gum.LazyPropagation(self.r_bn)
        self.ie.makeInference()
        gnb.showProba(self.ie.posterior(self.I))
#         gnb.showInference(self.r_bn)
    
#         gnb.showProba(self.r_bn.cpt(self.A))
        # gnb.showPotential(self.r_bn.cpt(self.r_bn.idFromName('I')),digits=3) # ->not working! Doesn't show the posterior
        
        # self.r_bn.cpt(self.I).fillWith([0.3,0.5])
        # gnb.showInference(self.r_bn)
        
#         self.r_bn.variable(0).toLabelizedVar().changeLabel(0, "toto").changeLabel(1, "moto") #->not working!!! Bad Cast error

        '''Update the variable when a new person is added to the database'''
#         self.r_bn.erase(self.I)
#         gnb.showBN(self.r_bn)
#         self.identity.setMaxVal(2)
#         self.I = self.r_bn.add(self.identity)
#         gnb.showBN(self.r_bn)
        
#         self.r_bn.erase(self.F)
#         gnb.showBN(self.r_bn)
#         self.face.setMaxVal(3)
#         self.F = self.r_bn.add(self.face)
#         gnb.showBN(self.r_bn)
#         self.r_bn.cpt(self.I).fillWith([0.6,0.5,0.3])
#         self.r_bn.cpt(self.F).fillWith([0.5,0.5,0.5,0.5])
#         gnb.showInference(self.r_bn)
        '''
        #TODO: find how to do the curve using confidence as mean and truncated norm curve with boundaries! (ask Valerio) 
        
        age_y = norm(loc = -1., scale = 1.0)

        age_x = linspace(-10, 10, 100)
        
        = age_y.pdf(age_x)
    '''
    
    def updatePriors(self):
        # recog_results = self.recognise()
        recog_results = [ [ 0.756, [ [ "Bahar", 0.48 ], ["Unknown", 0.2] ] ], [ "Female", 0.7 ], [ 23, 0.666 ], 0.528664, [ "23:16:47", "2", "21", "March", "2017" ] ]
        
#         # P(A_F), P(F|A_F), P(G), P(A), P(H), P(T)
#         self.r_bn.cpt(self.A_F).fillWith([recog_results[0][0], 1 - recog_results[0][0]])
#         r_results_names = []
#         for counter in range(0, len(recog_results[0][1])):
#             r_results_names.append(recog_results[0][1][counter][0])
        
#         r_results_index = []
#         for counter in range(0, len(self.i_labels)):
#             r_results_index.append(r_results_names.index(self.i_labels[counter]))
#         print r_results_index
        
#         for counter in range(0, len(self.i_labels)):
#             # values are normalised when using this method
#             #TODO: think about non-reliable case (should I change the values or use accuracy in weighted arc???)
#             self.r_bn.cpt(self.F)[:,counter] = recog_results[0][1][r_results_index[counter]][1]
#         if recog_results[1][0] == "Female":
#             self.r_bn.cpt(self.G)[0] = recog_results[1][1] #Female
#             self.r_bn.cpt(self.G)[1] = 1-recog_results[1][1] #Male
#         else:
#             self.r_bn.cpt(self.G)[0] = 1-recog_results[1][1]
#             self.r_bn.cpt(self.G)[1] = recog_results[1][1]
        current_time = recog_results[4][0].split(":")
        numeric_day_name = recog_results[4][1]
        current_time_slot = (int(numeric_day_name)-1)*24*60/self.period + int(current_time[0])*60/self.period + int(current_time[1])/self.period
        time_curve = norm(loc=current_time_slot,scale=self.stddev_time)
        sum_time_pdfs = 0
        time_pdfs = []
        for time_i in range(0, self.num_time_slots):
            time_pdfs.append(time_curve.pdf(time_i))
            sum_time_pdfs += time_curve.pdf(time_i)
        norm_time_pdfs = [x / sum_time_pdfs for x in time_pdfs]
        self.r_bn.cpt(self.T)[:] = norm_time_pdfs
#         self.r_bn.cpt(self.A).fillWith(1).normalize()
#         self.r_bn.cpt(self.H).fillWith(1).normalize()
        
        # P(I|F), P(I|G), P(I|A), P(I|H), P(I|T)
        # TODO: when the time and date doesn't fit anyone (23:10:00 wednesday is not 10:00 or 12:00 wednesday) 
        # need to use "unknown" for preventing errors (otherwise joint probability is zero so it will give an error)
        self.ie = gum.LazyPropagation(self.r_bn)
        self.ie.setEvidence({'T':current_time_slot})
        self.ie.makeInference()
        print(self.ie.posterior(self.I))
        
    def recognise(self):
        recog_results = self.recog_service.recognisePerson()
        # TODO: SAVE THESE INITIAL RESULTS IN CASE THE PATIENT IS NOT REGISTERED (TO BE USED FOR LATER ANALYSIS)
        # TODO: ask TONY about the time and height variable!
        # TODO: get "register person" button from tablet (isRegistered = 0 if button is pressed)
        # TODO: add non-memory robot version
        # TODO: turn names into lower-case letters starting with an upper-case letter
        # TODO: get picture from tablet and send it to the robot
        isRegistered = 1
        isInDB = 1
        if isRegistered:
            # TODO: suggest name to tablet and robot will say name
            # if the name is not correct get p_name from tablet
            # check p_name is in db
            if not isInDB: 
                isRegistered = 0
                # TODO: ask name again, check db again otherwise alert the patient has not been registered 
                # and direct to registration screen 
            else:
                if recog_results[0][1][0][0] != person[0]:
                    learn_face_success = self.recog_service.addPictureToPerson(person[0])
                    # TODO: add image to person in DB(only if it is successful)
                    # if learn_face_success:
                        # save image to db
            
        if not isRegistered:
            # TODO: get person data from tablet if is not registered person = [p_name, p_gender, p_age, p_height])
            # TODO: get time from system and register time
            # TODO: check the db if the person is already registered 
            self.recog_service.registerPerson(person[0], person[1], person[2], person[3])
            self.updateNodes(person[0])
            # TODO: add person to db
            recog_results = self.recog_service.recognisePerson() # TODO: I am not sure, should I or should I use the previous results?!
        # TODO: save image in tablet with label = person[0]+number of images of person[0] (Jack001.jpg)
        return recog_results
        
if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument("--ip", type=str, default="127.0.0.1",
                        help="Robot IP address. On robot or Local Naoqi: use '127.0.0.1'.")
    parser.add_argument("--port", type=int, default=9559,
                        help="Naoqi port number")

#     args = parser.parse_args()
#     session = qi.Session()
#     try:
#         session.connect("tcp://" + args.ip + ":" + str(args.port))
#     except RuntimeError:
#         print ("Can't connect to Naoqi at ip \"" + args.ip + "\" on port " + str(args.port) +".\n"
#                "Please check your script arguments. Run with -h option for help.")
#         sys.exit(1)
    session = ""
    RB = RecogniserBN(session)
# Out:
# /home/bahar/.local/lib/python2.7/site-packages/ipykernel/__main__.py:266: RuntimeWarning: invalid value encountered in double_scalars
# BN{nodes: 2, arcs: 1, domainSize: 4032, parameters: 6048, compression ratio: -50% }
# <I:Unknown> :: -nan /<I:Bahar> :: -nan
# <svg height="116pt" viewBox="0.00 0.00 62.00 116.00" width="62pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 112)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-112 58,-112 58,4 -4,4" stroke="none"/>
# <!-- I -->
# <g class="node" id="node1"><title>I</title>
# <g id="a_node1"><a xlink:title="(0) I">
# <ellipse cx="27" cy="-18" fill="#444444" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-14.3">I</text>
# </a>
# </g>
# </g>
# <!-- T -->
# <g class="node" id="node2"><title>T</title>
# ...
